# %%
'''0. List - De lijst hieronder is de reeks getallen tussen 1 en 10, een getal mist, probeer deze in de lijst te zetten en print het resultaat om te kijken of het is gelukt.'''
list1 = [1,2,3,4,5,6,8,9,10]

# %%
'''1. List - Hieronder staan 3 variabelen: a, b en c. a is een lijst, b is een float en c is een string. Voeg b en c toe aan het einde van lijst a. Print het resultaat om te kijken of het is gelukt.'''
a = ["kaart", "zon", 3]
b = 2.3
c = "pasta"

# %%
'''2. List - Verwijder alle elementen uit de onderstaande list door de pop() methode meerdere keren te gebruiken'''
gemixte_lijst = [5, 7, "tennis", "voetbal", 10, "hockey", "schaatsen"]
# Out:
# [5, 7, 'tennis', 'voetbal', 10]

# %%
'''3. Nested lists - De variabele hieronder is een lijst met items, waarvan een item weer een lijst is met daarin weer items. Kijk of je het woord "zon" kan printen door gebruik te maken van 2 indexen.
    Tip: indicing op die manier werkt als lijst[index][index]'''
nested = [54, "water", "lucht", [2, "zon", 7.0], "schaduw"]

# %%
'''4. Set - Maak een set van de woorden: "panini", "wrap", "tosti", "panini" en print het resultaat'''

# %%
'''5. Set - Gebruik een set om te kijken hoeveel unieke karakters er in de zin hieronder zitten, en print de lengte van die set.'''
zin = "Toen ze om zich heen keek was alles al weg, niet wetende waar het heen ging."

# %%
'''6. Tuples zijn voor data verzamelingen die niet meer veranderen, 
    bij lists, sets, dictionaries kan de data nog wel kan veranderen. Maak de juiste verzamelingen hieronder'''
klanten_vorig_jaar = 'Henk', 'Ana'
klanten_dit_jaar = 'Henk', 'Ana', 'Mees', 'Ana'
aantal_identieke_namen = 'Henk', 'Ana', 'Mees', 'Ana'

# %%
'''7. Dictionaries '''
# Dit is een voorbeeld van een simpele dictionary, de key is "code" en de value is 777
voorbeeld_dictionary = {"code": 77}
#TODO: maak een dictionary aan met je naam en leeftijd

# %%
''' 8. Dictionary - Probeer te begrijpen wat er hier gebeurd en maak de code af.'''
dict_1 = {'cursus': 'Opatel', 'dag': 1, 'blok':2}
print(dict_1)

#TODO Verander 'blok' naar 3, we zijn immers al bij blok 3 aangekomen.
dict_1[key] = value # Waarom zou dit nu een error geven?

#TODO Voeg een nieuwe key aan de dict toe 
dict_1[key] = value

#TODO Maak zelf een dict/Dictionary, en laat beantwoord vragen van de gebruiker
dict_2 = 
key = input("Wat wilt u weten?")
print(dict_2[key])

# %%
'''9. Dictionaries - Een bedrijf werkt liever met barcodes dan productnamen, maar een database
zodat de het juist product gevonden kan worden als een barcode scanned wordt, met de volgende data
barcode: 29398239, product: 'soja kookroom'
barcode: 02139299, product: 'stokbrood'
barcode: 02193888, product: 'kaas'
barcode: 99318298, product: 'wortel'
barcode: 18203888, product: 'brood'
'''

# %%
''' 10. Set - Probeer te begrijpen wat er hier gebeurd en maak de code af.'''
set_1 = {'Opatel', 1, 2, 3, 4, 'Hello'}
print(set_1)

#Dit werkt niet, want een set heeft geen keys
set_1['Opatel'] = value

#Dit werkt niet, want een set heeft geen volgorde
set_1[0] = value

#TODO Maak zelf een set
set_1 =

# %%
''' 11. Dictionary - Maak Marktplaats na'''
laptop = {'merk': 'asus',
          'staat': 'nieuw',
          'aanbieder': 'loes',
         'prijs':400}

#TODO Kan jij het merk als output geven uit de database?

#TODO Kan jij de prijs met een euroteken als output geven uit de database?

#TODO Kan jij de aanbieder met een hoofdletter als output geven uit de database?

#TODO doe hetzelfde voor een schoen

#TODO doe hetzelfde voor een auto
