# %%
''' 0. De eerste opdracht was om dit bestand te uploaden en te openen hier, goed gedaan! '''
# Out:
# ' 0. De eerste opdracht was om dit bestand te uploaden en te openen hier, goed gedaan! '

# %%
''' 1. Run deze code die 'hello world' als output geeft.
Tip: dit kan bijvoorbeeld met shift+enter, of het icoon naast opslaan hierboven.'''
print('Hello world')

# %%
''' 2. Selecteer deze cell.
Tip: dit kan door er links op te klikken.'''
# Out:
# ' 2. Selecteer deze cell.\nTip: dit kan door er links naast te klikken.'

# %%
''' 3. Maak hieronder een nieuwe cell.
Tip: dit kan door de cell te selecteren en 'b' van below te tikken.'''

# %%
''' 4. Maak hierboven een nieuwe cell.
Tip: dit kan door de cell te selecteren en 'a' van above te tikken.'''

# %%
''' 5. Verwijder deze cell.
Tip: dit kan door de cell te selecteren en 'd' van delete te tikken.'''

# %%
''' 6. Maak een nieuw Python Notebook aan.
Tip: kijk bij File of Bestand.'''

# %%
''' 7. Plak deze regel hier 20 keer onder.
Tip: ctrl+c kopieerd een hele regel (de zin hoeft niet geselecteerd te worden), 
ctrl+v plakt deze.'''

# %%
''' 8. Verwijder deze regel in een keer.
Tip: dit kan met ctrl+d.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''
''' Verwijder ook deze regel in een keer.'''

# %%
''' Snel klaar? Probeer deze opdrachten. U kunt altijd vragen naar meer opdrachten
    Bonus 1 - Krijg het maken en verwijderen van meerdere nieuwe cellen met sneltoetsen, boven en onder de huidige cell onder de knie. 
        Het scheelt op de lange termijn veel tijd.
        Tip: met 'pijltje omhoog' en 'pijltje omlaag' kunt u de selectie tussen verschillende cellen veranderen
    Bonus 2 - Vogel het verschil tussen ctrl/cmd+enter en shift+enter uit.'''
