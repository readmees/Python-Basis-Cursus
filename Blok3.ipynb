# %%
''' 0. Type - Raad de datatypes en controleer dit door het type te printen'''
print(type(123.456)) # Voorbeeld (raad eerst float)
1
50
102003.45
'ajdksfjs'
'102.454'
True
# Out:
# <class 'float'>
# True

# %%
''' 1. Datacasting - Maak een string en een int van een float and print het type'''
float_var = 123.456
print(float_var, '\nType:', type(float_var))

#TODO maak een int van float_var met int()
int_var = 
print(int_var, '\nType:', type(int_var))

#TODO maak een string van float_var met str()
str_var = 
print()

# %%
''' 2. Datacasting - Maak een string en een int van een boolean and print het type'''
bool_var = bool(True)
print(bool_var, '\nType:', type(bool_var))

#TODO schrijf hier je code:

# %%
''' 3a. String - Probeer te begrijpen wat er hier gebeurd en speel zelf met strings en maak de code af.
Tip string+string kan, maar ook string*3 is mogelijk'''
string = 'Ik ben Mees'
print('Mijn naam is:', string[7:])

# TODO Debug de volgende code
string_1 = 'Tekst'
string_2 = "Dit is hetzelfde, maar zorgt er bijvoorbeeld voor dat ik 'aanhalingstekens' ook kan opslaan in de variable"
string_3 = "Anders zal, er een error onstaan, "run" deze cell maar om te kijken"
string_4 = "U kunt dit oplossen door \ te gebruiken voor een aanhalingsteken \"Hello\""
string_5 = ''' Dit werkt op meerdere regels
Kijk maar
De enters worden ook opgeslagen
Enters kan ik ook opslaan door \n in een string te zetten'''

# TODO print uw naam met het alfabet
alfabet = 'abcdefghijklmnopqrstuvwxz'
naam = alfabet[12]+alfabet[4]*2+alfabet[-7]
print(naam)

# %%
''' 3b. Methods '''
# Print nu uw naam met een hoofdletter (Google mag, bijvoorbeeld 'capital string py')
# Zie ook https://www.w3schools.com/python/python_strings_methods.asp
print(naam.doeiets())

# Print nu de variable 'string' zonder spaties aan de voor en achterkant (zie slides)
print(string.doeiets())

# Print nu uw naam helemaal in hoofdletters (Google mag, bijvoorbeeld 'upper case string py')
print(naam.doeiets())

# Vervang een letter in uw naam met '!' (Google mag, bijvoorbeeld 'replace string py')
# Tip: tekst.replace('a', 'b') veranderd alle letters a in de letter b'''
print(naam.doeiets())

# %%
''' 3c. Vervang de naam in deze mail '''
email = '''
Goedendag {naam},

Graag zou ik u een mail schrijven over iets willekeurigs. 

Ik hoop van u te horen.

Met vriendelijke groet,

{andere_naam}
'''

naam = 
andere_naam = 
# Vervang naam
email = email.replace()
print(email)

# Vervang andere naam
email = email.replace()
print(email)

# %%
''' 4. fstring - Probeer te begrijpen wat er hier gebeurd en speel zelf met strings en maak de code af'''

email = '''
Goedendag {naam},

Graag zou ik u een mail schrijven over iets willekeurigs. 

Ik hoop van u te horen.

Met vriendelijke groet,

{andere_naam}
'''
print(email)

# Let op de f
email = f'''
Goedendag {naam},

Graag zou ik u een mail schrijven over iets willekeurigs. 

Ik hoop van u te horen.

Met vriendelijke groet,

{andere_naam}
'''
print(email)

# Dit kan ook voor andere variables dan strings, zie bijvoorbeeld
print(f'5 keer 3 is {5*3}')

# En werkt ook met strings met drie dubbele aanhalingstekens
print(f'''
4/2={4/2}
Mijn naam is {naam}
''')

# %%
''' 5. Boolean - Probeer te begrijpen wat er hier gebeurd en speel zelf met booleans'''
lijst_vol = [1,2,3,4]
lijst_leeg = []

# Een lege lijst is altijd False in Python, zo kan je bijvoorbeeld controleren of er waardes in een lijst zitten
print('De lijst lijst_leeg is gevuld:', bool(lijst_leeg))

# Een gevulde lijst is altijd True in Python
print('De lijst lijst_vol is gevuld:', bool(lijst_vol))

# Je kan ook kijken of een element in een lijst zit
print('De lijst lijst_vol is gevuld:', bool(3 in lijst_vol))

# Logica is mogelijk in Python not True is False en not not True is True
# Oftewel niet waar is onwaar en niet niet waar is waar
print('If something is not True, some would say it is', bool(not True))

# %%
''' VANAF HIER IS VOOR BLOK3b'''

# %%
''' 6. Lijst - Probeer te begrijpen wat er hier gebeurd en maak de code af.
Tip: indicing werkt hetzelfde als stringslicing.'''
lijst_1 = ['Mees', 23, 300, 'appel', 500]
print(lijst_1)

#TODO Print 'Mees' en 'Appel' uit de lijst

#TODO Verander 'Appel' naar 'Peer'

#TODO Vraag de gebruiker naar een fruit en verander 'Peer' voor dit fruit

#TODO Vraag de gebruiker 3 keer naar een fruit en voeg dit elke keer toe aan de lijst
lijst_1.append()

#TODO Geef nu het laatste stuk fruit dat de gebruiker als output had gegeven

# %%
''' 7. Tuple - Probeer te begrijpen wat er hier gebeurd en maak de code af.
Tip: indicing werkt hetzelfde als stringslicing.'''
tuple_1 = ('Mees', 23, 300, 'appel', 500)
print(tuple_1)

# Dit werkt niet, want een een tuple is NIET aanpasbaar
tuple_1.pop(2)
tuple_1.append(2)
tuple_1[0] = 'Mees Meester'

# Je kan een tuple wel kopieren in een lijst, dan deze lijst aanpassen en er dan weer een tuple van maken
#TODO Probeer dit hieronder, met behulp van tuple() en list()
# Tip: verwijder eerst het deel van de code hierboven dat niet werkt
lijst_van_tuple =

# %%
''' 7. Dictionary - Probeer te begrijpen wat er hier gebeurt en maak de code af.'''
dict_1 = {'cursus': 'Opatel', 'dag': 1, 'blok':3}
print(dict_1)

#TODO Verander 'blok' naar 3, we zijn immers al bij blok 3 aangekomen.
dict_1[key] = value # Waarom zou dit nu een error geven?

#TODO Voeg een nieuwe key aan de dict toe 
dict_1[key] = value

#TODO Maak zelf een dict/Dictionary, en laat beantwoord vragen van de gebruiker
dict_2 = 
key = input("Wat wilt u weten?")
print(dict_2[key])

# %%
''' 8. Set - Probeer te begrijpen wat er hier gebeurt en maak de code af.'''
set_1 = {'Opatel', 1, 2, 3, 4, 'Hello'}
print(set_1)

#Dit werkt niet, want een set heeft geen keys
set_1['Opatel'] = value

#Dit werkt niet, want een set heeft geen volgorde
set_1[0] = value

#TODO verwijder 'Opatel' en voeg 'Python' toe
#Tip: gebruik set.remove(element), set.add(element)

#TODO Maak zelf een set
set_1 =

# %%
''' Snel klaar? Probeer deze opdracht. U kunt altijd vragen naar meer opdrachten
    Bonus 1 - Schrijf een mail die op basis van een aantal variables automatisch gegenereerd wordt. 
        Vraag de gebruiker hoeveel producten gewenst zijn en genereer een mail met de prijs. 
        Tip: input is altijd een string, u moet dus casting gebruiken.
    Bonus 2 - Schrijf een mail die op basis van een aantal variables automatisch gegenereerd wordt. 
        Vraag de gebruiker welke producten gewenst zijn en genereer een mail met de prijs. 
        Tip: gebruik een list of een dictionary met producten.'''
